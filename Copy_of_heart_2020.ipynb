# %% [markdown]
# <a href="https://colab.research.google.com/github/Blessing-nwachukwu1/upgraded-octo-pancake/blob/main/Copy_of_heart_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![heartpix2.avif](data:image/avif;base64,...)

# %% [markdown]
# **INTRODUCTION**
#
# The health status of every individual can be affected by numerous factors. While some can not be changed (Race, age etc), some others can be modulated (Drinking habit, Physical excercise etc) invaraiably known as lifestyle.
# There is always a link between lifestyle and the health status of individuals. Though some lifestyle effects  can be very glaring, some others are negligible, kindly go through this analysis to see some factors affecting health status.

# %% [markdown]
# **ABOUT THE DATA SET:**
# HeartDisease : Respondents that have ever reported having coronary heart disease (CHD) or myocardial infarction (MI). BMI : Body Mass Index (BMI). Smoking : Have you smoked at least 100 cigarettes in your entire life? ( The answer Yes or No ). AlcoholDrinking : Heavy drinkers (adult men having more than 14 drinks per week and adult women having more than 7 drinks per week Stroke : (Ever told) (you had) a stroke? PhysicalHealth : Now thinking about your physical health, which includes physical illness and injury, for how many days during the past 30 days was your physical health not good? (0-30 days). MentalHealth : Thinking about your mental health, for how many days during the past 30 days was your mental health not good? (0-30 days). DiffWalking : Do you have serious difficulty walking or climbing stairs? Sex : Are you male or female? AgeCategory: Fourteen-level age category. Race : Imputed race/ethnicity value. Diabetic : (Ever told) (you had) diabetes? PhysicalActivity : Adults who reported doing physical activity or exercise during the past 30 days other than their regular job. GenHealth : Would you say that in general your health is... SleepTime : On average, how many hours of sleep do you get in a 24-hour period? Asthma : (Ever told) (you had) asthma? KidneyDisease : Not including kidney stones, bladder infection or incontinence, were you ever told you had kidney disease? SkinCancer : (Ever told) (you had) skin cancer?

# %% [markdown]
# IMPORTING THE LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# READING THE DATASETS

# %%
df =pd.read_csv("/content/heart_2020_cleaned.csv")
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 256296           No  35.51      No              No     No             0.0
# 256297          Yes  34.87     Yes              No     No             0.0
# 256298           No  31.66      No              No     No             0.0
# 256299           No  21.26      No              No     No             0.0
# 256300           No  24.33      No              No    NaN             NaN
#
#         MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# ...

# %% [markdown]
# There are a total of 256301 rows and 18 colunms in this dataset.

# %% [markdown]
# **DATA EXPLORATION**

# %%
df.shape
# Out:
# (256301, 18)

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 256296           No  35.51      No              No     No             0.0
# 256297          Yes  34.87     Yes              No     No             0.0
# 256298           No  31.66      No              No     No             0.0
# 256299           No  21.26      No              No     No             0.0
# 256300           No  24.33      No              No    NaN             NaN
#
# ...

# %% [markdown]
# SUMMARY OF STATISTICS

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  256301.000000   256300.000000  256300.000000  256300.000000
# mean       28.315776        3.337768       3.880862       7.102474
# std         6.354517        7.914159       7.933458       1.436154
# min        12.020000        0.000000       0.000000       1.000000
# 25%        24.030000        0.000000       0.000000       6.000000
# 50%        27.320000        0.000000       0.000000       7.000000
# 75%        31.380000        2.000000       3.000000       8.000000
# max        94.850000       30.000000      30.000000      24.000000

# %% [markdown]
# **DATA CLEANING**

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              1
# PhysicalHealth      1
# MentalHealth        1
# DiffWalking         1
# Sex                 1
# AgeCategory         1
# Race                1
# Diabetic            1
# PhysicalActivity    1
# GenHealth           1
# SleepTime           1
# Asthma              1
# KidneyDisease       1
# SkinCancer          1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 12646

# %%
df["AgeCategory"].unique()
# Out:
# array(['55-59', '80 or older', '65-69', '75-79', '40-44', '70-74',
#        '60-64', '50-54', '45-49', '18-24', '35-39', '30-34', '25-29', nan],
#       dtype=object)

# %% [markdown]
# Convert the 80 - older to 80-84

# %%
df['AgeCategory'] = df['AgeCategory'].replace('80 or older', '80-84')

# %%
def calculate_average_age(age_range):
  ages = age_range.split('-')
  lower_age = int(ages[0])
  upper_age = int(ages[1]) if len(ages) > 1 else lower_age
  return (lower_age + upper_age) / 2

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# **Q1 what is the percentage of people with hearth disease and people without Heart Disease respectively ?**

# %%
HeartDisease= df["HeartDisease"].value_counts()
HeartDisease
plt.pie(HeartDisease.values, labels=HeartDisease.index, colors=["lawngreen", "dimgray"], autopct="%1.1f%%")
plt.title("HeartDisease Data")
plt.show()

# %% [markdown]
# From this visualization we can deduce that individuals with heart disease are (8.6%) while those without heart disease are(91.4%).

# %% [markdown]
# **Q2. What AgeCategories are the highest and lowest?**

# %%
df.sort_values(by='AgeCategory' ,inplace=True)

# %%
sns.countplot(x=df["AgeCategory"],color='lawngreen')
plt.xlabel("AgeCategory")
plt.title("Count plot of AgeCategory")
# Out:
# Text(0.5, 1.0, 'Count plot of AgeCategory')

# %% [markdown]
# This is the distribution of ag the age category accross many age groups. The age Category with the highest number of people are 65 - 69 group. While 25-29 are the lowest in population.

# %% [markdown]
# **Q3 Which age category has the highest heart disease rate ?**

# %%
df_grouped = df.groupby(['AgeCategory', 'HeartDisease'])

# %%
df_grouped = df.groupby(['AgeCategory', 'HeartDisease']).size().unstack()
df_grouped.plot(kind = "bar", stacked = True, color = ["lawngreen", "black"])
plt.title("Prevalence of heart Disease Among Age Categories")
plt.xlabel("Age category")
plt.legend(["No Heart disease", "Heart Disease"],)

# %% [markdown]
# The age group 80-84 has the highest heart disease rates.

# %% [markdown]
# **Q4 What is the Smoking Rate of these patients ?**

# %%
Smoking_rate=df['Smoking'].value_counts()
#create a pieplot
plt.pie(Smoking_rate.values, labels =Smoking_rate.index, colors=['deepskyblue','greenyellow'],autopct='%1.1f%%')

#add a circle at the centre to make a donut chart
my_circle=plt.Circle((0,0),0.75, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %% [markdown]
# This visualisation shows that there are more in number patients who do no smoke (58.1%), than Patients who smoke(41.9).

# %% [markdown]
# **Q5 How does the prevalence of smoking vary amongst the age categories ?**

# %%
sns.barplot(df, x= df["AgeCategory"], y= df["Smoking"], color="dimgray" )
plt.xlabel("AgeCategory")
plt.title("Age category Vs Smoking")
# Out:
# Text(0.5, 1.0, 'Age category Vs Smoking')

# %% [markdown]
# From the diagram, the age category with the highest number of smokers are the 75 - 79 age bracket, while the age bracket with the lowest amont of smokers are 18-24 age bracket..

# %% [markdown]
# **Q6. Are individuals with stroke more likely to have a history of smoking ?**

# %%
sns.countplot(x = "Stroke", hue="Smoking", color='chartreuse', data=df)
plt.title("Smoking vs Stroke")
plt.xlabel("Stroke")
plt.ylabel("Smoking")
plt.show()
# Out:
# <ipython-input-29-65b530a3ede2>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:chartreuse'` for the same effect.
#
#   sns.countplot(x = "Stroke", hue="Smoking", color='chartreuse', data=df)

# %% [markdown]
# Though majority of this population do not smoke, but from the population that smokes: patients who smoke have higher Stroke rate. Therefore, smoking may be a contributing factor to Stroke.

# %% [markdown]
# **Exploring BMI**

# %%
plt.hist(df["BMI"], color= 'aqua')
plt.title("BMI Distribution of Clients")
plt.xlabel("bmi")
# Out:
# Text(0.5, 0, 'bmi')

# %% [markdown]
# **Q7. Is there any relationship between BMI and Walking Difficulty?**

# %%
sns.boxplot(x = "BMI", hue="DiffWalking", color='aqua', data=df)
plt.title("Relationship between BMI and Walking Difficulty")
plt.xlabel("BMI")
plt.ylabel("difficulty in walking")
plt.show()
# Out:
# <ipython-input-31-0ce6285017be>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:aqua'` for the same effect.
#
#   sns.boxplot(x = "BMI", hue="DiffWalking", color='aqua', data=df)

# %% [markdown]
# Individuals who had BMI above 30 had more walking difficulty than individuals whose BMI were relatievly below 30.

# %% [markdown]
# **Exploring Diabetics rate**

# %%
Diabetic = df["Diabetic"].value_counts()
plt.pie(Diabetic.values, labels=Diabetic.index, colors= ["aquamarine","lawngreen"],autopct="%1.1f%%")
plt.title("Diabetics rate")
plt.show()

# %% [markdown]
# A good percentage of the population do not have diabetics (84.4%), 12.7% have diabetics, 2.2%(No) borderline diabetics and 0.8% have diabetics only during pregnancy.

# %% [markdown]
# **Q8 What is the relationship between BMI and diabetics ?**

# %%
sns.barplot(x = "BMI", hue="Diabetic", color ='lawngreen', data=df)
plt.title("BMI vs DIABETICS")
plt.xlabel("BMI")
plt.ylabel("DIABETICS")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7c15d4ddb462> in <cell line: 1>()
# ----> 1 sns.barplot(x = "BMI", hue="Diabetic", color ='lawngreen', data=df)
#       2 plt.title("BMI vs DIABETICS")
#       3 plt.xlabel("BMI")
#       4 plt.ylabel("DIABETICS")
#       5 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# There is a significant positive relationship between BMI level and Diabetic state. From the figure above, the individuals with Diabetics(Yes), have their BMI above 30, but those without Diabetics(NO) have their BMI between between 25-30. This shows that people with BMI above 30 are more likely to develope diabetes than those whose bMI are below 30.

# %% [markdown]
# **Physcical Health of individuals**

# %%
sns.violinplot(x=df["PhysicalHealth"],color='lawngreen')
plt.xlabel("Physical Health")
plt.title("Physical Health of Individuals")
# Out:
# Text(0.5, 1.0, 'Physical Health of Individuals')

# %% [markdown]
# This visualization shows different ranges of the physical health of individuals. The physical health of most individuals are below 5.

# %% [markdown]
# **Q9 What is the relationship between Physical Health and the Mental Health of the individuals ?**

# %%
sns.scatterplot(df, x ="PhysicalHealth", y= "MentalHealth", color='greenyellow')
plt.xlabel("Physical Health")
plt.ylabel("Mental Health")
plt.title("Physical Health Vs Mental Health")
# Out:
# Text(0.5, 1.0, 'Physical Health Vs Mental Health')

# %% [markdown]
# There is no significant relationship between Physical health and mental health scores.

# %% [markdown]
# **Exploring Gender**

# %%
sns.countplot(x=df["Sex"],color='lime')
plt.xlabel("Sex")
plt.title("Sex of individuals")
# Out:
# Text(0.5, 1.0, 'Sex of individuals')

# %% [markdown]
# From our visualization, there are more females than males.

# %% [markdown]
# **Q10 Which Gender is more likely to Smoke ?**

# %%
sns.countplot(x = "Sex", hue="Smoking", color='aquamarine', data=df)
plt.title("Rate of Smoking between the different Genders")
plt.xlabel("Sex")
plt.ylabel("Smoking")
plt.show()
# Out:
# <ipython-input-37-c401991c2a66>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:aquamarine'` for the same effect.
#
#   sns.countplot(x = "Sex", hue="Smoking", color='aquamarine', data=df)

# %% [markdown]
# From the Visualization, the female gender are more likely to smoke than the males. Though the females who do not smoke are almost half of the number of those who smoke while the margin between males who smoke and males who do not is little.

# %% [markdown]
# **Q11. Is there a difference in the prevalence of heart disease between the genders ?**

# %%
df_grouped = df.groupby(['Sex', 'HeartDisease']).size().unstack()
df_grouped.plot(kind = "bar", stacked = True, color = ["lawngreen", "black"])
plt.title("Prevalence of Heart Disease amongst Genders")
plt.xlabel("Sex")
plt.legend(["No Heart disease", "Heart Disease"],)

# %% [markdown]
# Yes, from the visualization the males have more heart disease rates than the female population.

# %% [markdown]
# **Q12. Which Race dominates the population ?**

# %%
Smoking_rate=df['Race'].value_counts()
#create a pieplot
plt.pie(Smoking_rate.values, labels =Smoking_rate.index, colors=['black','gold'],autopct='%1.1f%%')

#add a circle at the centre to make a donut chart
my_circle=plt.Circle((0,0),0.75, color='aquamarine')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %% [markdown]
# From the visualization, the patients are predominantly Whites and the minority are American Indian/Alaskan Native.

# %% [markdown]
# **Q13. Which race is more suceptible to skin cancer?**

# %%
df_grouped = df.groupby(['Race', 'SkinCancer']).size().unstack()
df_grouped.plot(kind = "bar", stacked = True, color = ["aqua", "gold"])
plt.title("Race Vs Skin Cancer")
plt.xlabel("Race")
plt.legend(["No Skin cancer", "Skin cancer"],)

# %% [markdown]
# The whites are more susceptible to skin Cancer than any other race in this polpulation

# %% [markdown]
# **Exploring Physical Activity**

# %%
sns.countplot(x=df["PhysicalActivity"],color='aquamarine')
plt.xlabel("Physical Activity")
plt.title("Box plot of Physical Activity")
# Out:
# Text(0.5, 1.0, 'Box plot of Physical Activity')

# %% [markdown]
# **Q14. Is there any relationship between Physical activity and SleepTime ?**

# %%
sns.barplot(df, x ="SleepTime", y= "PhysicalActivity", color='greenyellow')
plt.xlabel("Sleep Time")
plt.ylabel("Physical Activity")
plt.title("sleep Time Vs Physical Activity")
# Out:
# Text(0.5, 1.0, 'sleep Time Vs Physical Activity')

# %% [markdown]
# There is no significant relationship between physical Activity and individual's Sleep Time.

# %% [markdown]
# **Q15. What is the Correlation between Physical Activity and Sleep time ?**

# %%
sns.scatterplot(df, x ="MentalHealth", y= "SleepTime", color='aqua')
plt.xlabel("Mental Health")
plt.ylabel("Sleeptime")
plt.title("Mental Health Vs Sleep Time")
# Out:
# Text(0.5, 1.0, 'Mental Health Vs Sleep Time')

# %% [markdown]
# There is no strong correlation between mental Health State and Sleep Time because the points vary almost same accross all the data points.

# %% [markdown]
# **Q16. Are there any associations between kidney disease and alcohol consumption ?**

# %%
sns.countplot(x = "KidneyDisease", hue="AlcoholDrinking", color='gold', data=df)
plt.title("Kidney Disesse Vs Alcohol Consumption")
plt.xlabel("Kidney disease")
plt.ylabel("Alcohol Consumption")
plt.show()
# Out:
# <ipython-input-44-2d70d8c1cdf7>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:gold'` for the same effect.
#
#   sns.countplot(x = "KidneyDisease", hue="AlcoholDrinking", color='gold', data=df)

# %% [markdown]
# There is no significant association between alcohol consumption and Kidney disease.

# %% [markdown]
# **SUMMARY**
#
# The health statistics of 256301 patients who had either Coronary heart disease (CHD) or Myocardial Infarction(M.I). There were about 25631 rows and  18 colunms which included 'HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke','PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory','Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime', 'Asthma', 'KidneyDisease', 'SkinCancer'. The data was explored, cleaned and
# Anlysed using various statistics and analytical skills in python. Different Libraries were used for the data analysis and exploration which includes; pandas imported as pd, numpy imported as np, matplotlib.pyplot imported as plt and Seaborn imported as sns. The methods of data analysis varied between Univariate and bivariate analysis where Univariate analysis was used to explore only numerical or categorical variables respectively and bivariate was used to analyse numerical and categorical variables as the case required using models of count, bar, pie, hist, dough and box plots.

# %% [markdown]
# **CONCLUSION**
#
# From the exploration and analysis above, factors such as  younger age, BMI between 20 and 30   had a very strong positive relationship to good health. Factors such as Physical health score, sleeptime, mental health scores etc had fair relationship to good health. While factors such as smoking, advanced age, BMI above 30 etc, had a very strong negative relationship to good health. Other findings are: There was no significant relationship between alcohol consumption and kidney disease, males are more prone to develop a heart disease, whites are more susceptible to cancer. Therefore there is need for people to maintain a good BMI, avoid smoking etc. There is a need for the male gender to be more careful about their health, The Whites should avoid carcinogens by every means possible since they ae more susceptible to skin cancer.
